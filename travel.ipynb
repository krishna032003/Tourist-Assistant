# %% [markdown]
# # 🌍 Tourist Assistant (Free Version)
#
# This notebook runs the complete Tourist Assistant application using the Google Gemini free tier, Google's free TTS/STT, and the Google Places API.
#
# **Instructions:**
# 1.  Create a `.env` file in this folder with your Google API keys.
# 2.  Run the cells in order.
# 3.  The final cell will launch the web interface.

# %%
# This cell installs all the new and existing libraries required for the project.
# !pip install gradio python-dotenv pydub pypdf langchain langchain-community faiss-cpu requests
# !pip install google-generativeai langchain-google-genai gTTS SpeechRecognition
print("✅ All libraries installed successfully.")
# Out:
# Requirement already satisfied: gradio in c:\users\krish\anaconda3\envs\llms\lib\site-packages (5.46.0)
# Requirement already satisfied: python-dotenv in c:\users\krish\anaconda3\envs\llms\lib\site-packages (1.1.1)
# Requirement already satisfied: pydub in c:\users\krish\anaconda3\envs\llms\lib\site-packages (0.25.1)
# Requirement already satisfied: pypdf in c:\users\krish\anaconda3\envs\llms\lib\site-packages (6.0.0)
# Requirement already satisfied: langchain in c:\users\krish\anaconda3\envs\llms\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-community in c:\users\krish\anaconda3\envs\llms\lib\site-packages (0.3.29)
# Requirement already satisfied: faiss-cpu in c:\users\krish\anaconda3\envs\llms\lib\site-packages (1.12.0)
# Requirement already satisfied: requests in c:\users\krish\anaconda3\envs\llms\lib\site-packages (2.32.5)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.115.9)
# Requirement already satisfied: ffmpy in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.13.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (1.13.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.34.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (2.3.1)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (11.2.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (2.11.4)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.11.12)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio-client==1.13.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gradio-client==1.13.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.18.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain) (0.3.45)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: greenlet>=1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-community) (3.12.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: google-generativeai in c:\users\krish\anaconda3\envs\llms\lib\site-packages (0.8.5)
# Requirement already satisfied: langchain-google-genai in c:\users\krish\anaconda3\envs\llms\lib\site-packages (2.0.10)
# Requirement already satisfied: gTTS in c:\users\krish\anaconda3\envs\llms\lib\site-packages (2.5.4)
# Requirement already satisfied: SpeechRecognition in c:\users\krish\anaconda3\envs\llms\lib\site-packages (3.14.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (1.34.1)
# Requirement already satisfied: google-api-python-client in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (2.170.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (2.40.2)
# Requirement already satisfied: protobuf in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (3.20.2)
# Requirement already satisfied: pydantic in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (2.11.4)
# Requirement already satisfied: tqdm in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-generativeai) (4.13.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.49.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-google-genai) (0.3.76)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from gTTS) (8.1.8)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from click<8.2,>=7.1->gTTS) (0.4.6)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.9)
# Requirement already satisfied: sniffio in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.1)
# Requirement already satisfied: h11>=0.16 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.16.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\krish\anaconda3\envs\llms\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# ✅ All libraries installed successfully.

# %%
# This cell loads all the keys from your .env file.
# Your .env file should contain:
# GOOGLE_API_KEY="YOUR_GEMINI_API_KEY"
# GOOGLE_PLACES_API_KEY="YOUR_GOOGLE_PLACES_KEY"

import os
from dotenv import load_dotenv

load_dotenv(override=True)

# --- Load all Environment Variables ---
print("--- Loading variables from .env file... ---")
google_api_key = os.getenv("GOOGLE_API_KEY")
google_places_api_key = os.getenv('GOOGLE_PLACES_API_KEY')

# --- Verification Step ---
def verify_var(var_name, var_value, is_secret=False):
    if var_value:
        display_value = f"{var_value[:5]}..." if is_secret else var_value
        print(f"✅ {var_name}: {display_value} (Loaded)")
    else:
        print(f"❌ {var_name}: NOT FOUND. Check your .env file.")

print("\n--- Verifying loaded variables ---")
verify_var("GOOGLE_API_KEY", google_api_key, is_secret=True)
verify_var("GOOGLE_PLACES_API_KEY", google_places_api_key, is_secret=True)
print("--------------------------------")
# Out:
# --- Loading variables from .env file... ---
#
# --- Verifying loaded variables ---
# ✅ GOOGLE_API_KEY: AIzaS... (Loaded)
# ✅ GOOGLE_PLACES_API_KEY: AIzaS... (Loaded)
# --------------------------------

# %%
# This cell initializes and tests the core AI models from Google.
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
import google.generativeai as genai

print("--- Initializing Google Gemini clients... ---")
try:
    genai.configure(api_key=google_api_key)
    llm = ChatGoogleGenerativeAI(model="models/gemini-2.5-flash", temperature=0.7)
    embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
    print("✅ Google Gemini clients initialized successfully.")

    print("\n--- Testing Chat Model (Gemini 2.5 Flash)... ---")
    response = llm.invoke("Hello, world!")
    print(f"✅ SUCCESS! Chat model replied: '{response.content}'")

    print("\n--- Testing Embeddings Model (Gemini 2.5 Flash)... ---")
    vector = embeddings.embed_query("This is a test sentence.")
    print(f"✅ SUCCESS! Embeddings model created a vector of length: {len(vector)}.")
    
except Exception as e:
    print(f"❌ FAILED to initialize or test clients. Error: {e}")
    print("   Please double-check your GOOGLE_API_KEY in the .env file.")
# Out:
# --- Initializing Google Gemini clients... ---
# ✅ Google Gemini clients initialized successfully.
#
# --- Testing Chat Model (Gemini 2.5 Flash)... ---
# ✅ SUCCESS! Chat model replied: 'Hello there!
#
# "Hello, world!" back to you! It's a classic for a reason. How can I help you today?'
#
# --- Testing Embeddings Model (Gemini 2.5 Flash)... ---
# ✅ SUCCESS! Embeddings model created a vector of length: 768.

# %%
# This cell tests the connection to the Google Places API.
import requests

print("--- Testing Google Places API... ---")

if not google_places_api_key:
    print("❌ FAILED: GOOGLE_PLACES_API_KEY was not found in your .env file.")
else:
    print(f"✅ Google API Key loaded successfully, starting with: {google_places_api_key[:8]}...")
    test_location = "Eiffel Tower in Paris"
    url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={test_location}&key={google_places_api_key}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status() 
        data = response.json()
        
        if data['status'] == 'OK':
            print("✅ SUCCESS! Google Places API connection is working.")
            print(f"   Test search found: '{data['results'][0]['name']}'.")
        else:
            print(f"❌ FAILED: The API returned a status of '{data['status']}'.")
            if 'error_message' in data:
                print(f"   API Error Message: {data['error_message']}")

    except requests.exceptions.RequestException as e:
        print(f"❌ FAILED: A network error occurred. Error: {e}")
# Out:
# --- Testing Google Places API... ---
# ✅ Google API Key loaded successfully, starting with: AIzaSyAr...
# ✅ SUCCESS! Google Places API connection is working.
#    Test search found: 'Eiffel Tower'.

# %%
# This cell contains the complete, final code for the application.
# It relies on all the clients and variables created in the cells above.

import gradio as gr
import requests
import glob
import os  # <-- ADDED
import threading  # <-- ADDED
from io import BytesIO  # <-- ADDED
from pypdf import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from pydub import AudioSegment
from playsound import playsound
from gtts import gTTS
import speech_recognition as sr
from langchain_core.messages import HumanMessage, AIMessage

# --- RAG Functions and Initialization ---
def read_pdf(file_path):
    pdf_reader = PdfReader(file_path)
    text = ""
    for page in pdf_reader.pages:
        text += page.extract_text() or ""
    return text

def load_knowledge_base():
    os.makedirs("knowledge-base", exist_ok=True)
    pdf_files = glob.glob("knowledge-base/*.pdf")
    if not pdf_files: return None
    all_content = "".join(read_pdf(pdf_file) + "\n\n" for pdf_file in pdf_files)
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200, length_function=len)
    chunks = text_splitter.split_text(all_content)
    # Use the Google embeddings client initialized in the previous cell
    return FAISS.from_texts(chunks, embeddings)

vector_store = load_knowledge_base()
retrieval_chain = None
if vector_store:
    # Use the Google LLM client initialized in the previous cell
    retrieval_chain = ConversationalRetrievalChain.from_llm(
        llm=llm,
        retriever=vector_store.as_retriever(search_kwargs={"k": 3}),
        return_source_documents=False
    )
    print("RAG system initialized successfully.")
else:
    print("RAG system not initialized (no PDFs found).")


# --- Core Application Functions ---
def talker(message):
    """Converts text to speech using gTTS and plays it with playsound."""
    
    if not message or message.strip() == "":
        print("No text to speak, skipping audio playback.")
        return

    try:
        tts = gTTS(text=message, lang='en')
        local_audio_file = "temp_playback.mp3"
        tts.save(local_audio_file)

        def play_audio():
            try:
                playsound(local_audio_file)
            except Exception as e:
                print(f"Error during audio playback: {e}")
            finally:
                if os.path.exists(local_audio_file):
                    try:
                        os.remove(local_audio_file)
                    except Exception as e:
                        print(f"Warning: Could not delete temp audio file. Error: {e}")
        
        playback_thread = threading.Thread(target=play_audio)
        playback_thread.start()
        
    except Exception as e:
        print(f"An error occurred during gTTS synthesis: {e}")
        
def transcribe_audio(audio_path):
    """Converts an audio file to text using Google's free web speech API."""
    if not audio_path: return "No audio detected."
    try:
        sound = AudioSegment.from_file(audio_path)
        wav_path = "temp_audio.wav"
        sound.export(wav_path, format="wav")
        
        r = sr.Recognizer()
        with sr.AudioFile(wav_path) as source:
            audio_data = r.record(source)
            text = r.recognize_google(audio_data)
            return text
    except sr.UnknownValueError:
        return "Speech recognition could not understand audio"
    except sr.RequestError as e:
        return f"Speech recognition service error; {e}"
    except Exception as e:
        print(f"An error occurred during transcription: {e}")
        return "Error during transcription."
    finally:
        if os.path.exists("temp_audio.wav"):
            os.remove("temp_audio.wav")

def search_attractions(location):
    if not google_places_api_key: return {"error": "Google Places API Key not set."}
    try:
        geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={google_places_api_key}"
        geocode_response = requests.get(geocode_url)
        geocode_data = geocode_response.json()
        if geocode_data["status"] != "OK" or not geocode_data["results"]:
            return {"error": f"Location not found: {location}"}
        location_data = geocode_data["results"][0]
        lat, lng = location_data["geometry"]["location"]["lat"], location_data["geometry"]["location"]["lng"]
        params = {"location": f"{lat},{lng}", "radius": 5000, "type": "tourist_attraction", "key": google_places_api_key}
        places_response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json", params=params)
        places_data = places_response.json()
        attractions = [{"name": p["name"], "rating": p.get("rating", "N/A"), "vicinity": p.get("vicinity", "N/A")} for p in places_data.get("results", [])[:10]]
        return {"location": location_data["formatted_address"], "attractions": attractions}
    except Exception as e:
        return {"error": str(e)}

system_message = (
    "You are a helpful and concise tourist assistant. "
    "Keep your answers to 2-3 sentences, unless the user asks for more detail. "
    "Help the user by providing good explanations about cities or places."
)

def extract_location(message):
    try:
        prompt = f"Extract the location from the following text. If no location is mentioned, return 'None'. Return only the location name.\n\nText: \"{message}\""
        response = llm.invoke(prompt)
        location = response.content.strip()
        return None if location.lower() in ['none', 'not specified'] else location
    except Exception as e:
        print(f"Error extracting location: {e}")
        return None

def chat(history):
    # Convert Gradio's history to LangChain's message format
    chat_history_messages = []
    for user_msg, bot_msg in history[:-1]: # All but the latest
        if user_msg:
            chat_history_messages.append(HumanMessage(content=user_msg))
        if bot_msg:
            chat_history_messages.append(AIMessage(content=bot_msg))

    latest_user_message = history[-1][0] if history and history[-1][0] else ""
    
    # Prepend the system message to the latest query
    full_prompt = [HumanMessage(content=system_message + "\n\nUser query: " + latest_user_message)]
    
    # Add context (location, RAG)
    location = extract_location(latest_user_message) if not (current_location and "attractions" in latest_user_message.lower()) else current_location
    if location and google_places_api_key:
        attractions_data = search_attractions(location)
        if "error" not in attractions_data and attractions_data.get("attractions"):
            attraction_context = f"\n\nHere is some context about attractions in {attractions_data['location']}:"
            for att in attractions_data["attractions"]:
                attraction_context += f"\n- {att['name']} (Rating: {att['rating']})"
            full_prompt[0].content += attraction_context # Add context to the prompt
            
    if retrieval_chain and latest_user_message:
        try:
            rag_response = retrieval_chain.invoke({"question": latest_user_message, "chat_history": chat_history_messages})
            reply = rag_response["answer"]
            unhelpful_phrases = [
                "i don't know", "i'm sorry", "i cannot answer",
                "the context does not", "based on the provided",
                "the document does not contain", "the information provided"
            ]
            is_unhelpful = any(phrase in reply.lower() for phrase in unhelpful_phrases)
            if is_unhelpful:
                print("RAG response was unhelpful, falling back to general LLM.")
                response = llm.invoke(full_prompt + chat_history_messages) 
                reply = response.content
        except Exception as e:
            print(f"RAG Error: {e}")
            response = llm.invoke(full_prompt + chat_history_messages)
            reply = response.content
    else:
        response = llm.invoke(full_prompt + chat_history_messages)
        reply = response.content
    
    talker(reply)
    return reply

# --- Load CSS ---
try:
    with open('style.css', 'r') as f:
        css = f.read()
except FileNotFoundError:
    print("Warning: style.css not found. Using default styles.")
    css = "" # Define css as an empty string to avoid errors

current_location = None

def refresh_knowledge_base():
    global vector_store, retrieval_chain
    vector_store = load_knowledge_base()
    if vector_store:
        retrieval_chain = ConversationalRetrievalChain.from_llm(
            llm=llm,
            retriever=vector_store.as_retriever(search_kwargs={"k": 3}),
            return_source_documents=False
        )
        return "Knowledge base refreshed successfully!"
    else:
        retrieval_chain = None
        return "No PDFs found. RAG is disabled."
        
def set_location(location):
    global current_location
    if not location or not location.strip(): return "Please enter a valid location."
    current_location = location
    return f"Location set to: {location}."

with gr.Blocks(theme="default", css=css) as ui:
    with gr.Column(elem_classes="container"):
        gr.Markdown("# 🌍 Tourist Assistant", elem_classes="title")
        gr.Markdown("Your personal guide to the wonders of the world.", elem_classes="subtitle")
        gr.Image("travel.jpg", show_label=False, container=False, height=200)
        chatbot = gr.Chatbot(height=450, elem_classes="chatbot-container", type="messages")
        with gr.Row(elem_classes="input-container"):
            audio_input = gr.Audio(sources=["microphone"], type="filepath", label="Speak your question", elem_id="mic-button")
            entry = gr.Textbox(placeholder="Or type your question here...", label="Text Input", show_label=False, scale=5)
        with gr.Accordion("⚙️ Settings & Tools", open=False, elem_classes="settings-accordion"):
            with gr.Tabs():
                with gr.TabItem("📍 Location"):
                    with gr.Row():
                        location_input = gr.Textbox(label="Set Current Location", placeholder="e.g., Paris, France")
                        location_btn = gr.Button("Set Location", variant="primary")
                    attractions_btn = gr.Button("Find Nearby Attractions", variant="secondary")
                    location_status = gr.Textbox(label="Location Status", interactive=False)
                with gr.TabItem("📚 Knowledge Base"):
                    refresh_btn = gr.Button("🔄 Refresh Knowledge Base", variant="primary")
                    refresh_status = gr.Textbox(label="KB Status", interactive=False)
            clear = gr.Button("🗑️ Clear Chat History")

        # --- Wire up the UI events ---
        def user(user_message, history):
            return "", history + [{"role": "user", "content": user_message}]

        def bot(history):
            history_for_backend = []
            for i in range(0, len(history), 2):
                if i + 1 < len(history):
                    user_msg = history[i]['content']
                    assistant_msg = history[i + 1]['content']
                    history_for_backend.append([user_msg, assistant_msg])
            latest_user_message = history[-1]['content']
            history_for_backend.append([latest_user_message, None])
            response = chat(history_for_backend)
            history.append({"role": "assistant", "content": response})
            return history

        def transcribe_and_chat(audio_path, history):
            if not audio_path: return history, gr.update(value=None)
            transcription = transcribe_audio(audio_path)
            history.append({"role": "user", "content": transcription})
            return bot(history), gr.update(value=None)
            
        entry.submit(user, [entry, chatbot], [entry, chatbot], queue=False).then(bot, chatbot, chatbot)
        audio_input.stop_recording(transcribe_and_chat, [audio_input, chatbot], [chatbot, audio_input])
        clear.click(lambda: [], None, chatbot, queue=False)
        refresh_btn.click(refresh_knowledge_base, None, refresh_status)
        location_btn.click(set_location, location_input, location_status).then(lambda: "", None, location_input)

        def ask_about_attractions(history):
            if not current_location:
                history.append({"role": "assistant", "content": "Please set a location first."})
                return history
            question = f"What are some attractions in {current_location}?"
            history.append({"role": "user", "content": question})
            return bot(history)
            
        attractions_btn.click(ask_about_attractions, chatbot, chatbot)

print("--- Full application code loaded. You can now launch the UI in the next cell. ---")
# Out:
# RAG system initialized successfully.
# --- Full application code loaded. You can now launch the UI in the next cell. ---

# %%
# If all previous cells ran successfully, this final cell will start the Gradio web server
# and launch the user interface in your browser.

print("--- Launching Gradio UI... ---")
ui.launch(inbrowser=True, debug=True)
# Out:
# --- Launching Gradio UI... ---
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
